# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv("AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 534.0 MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (6362620, 11)

# %%
round((df["isFraud"].value_counts()[1] / df.shape[0]) * 100 , 2)
# Out:
# np.float64(0.13)

# %%
df["type"].value_counts().plot(kind="bar", title= "Transaction Types" , color = "skyblue")
plt.xlabel("Transaction count")
plt.ylabel("Count")
plt.show()

# %%
fraoud_by_type = df.groupby("type")["isFraud"].mean().sort_values(ascending= False)
fraoud_by_type.plot(kind="bar", title= "Fraud by Types", color= "salmon")
plt.ylabel("Fraud rate")
plt.show()

# %%
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df["amount"]), bins= 100, kde= True , color= "green")
plt.title("Transaction Amount Distribution (long scale)")
plt.xlabel("log(Amouunt + 1)")
plt.show()

# %%
sns.boxplot(data=df[df["amount"]< 50000], x= "isFraud", y="amount")
plt.title("Amount vs isFraud (filtered undeer 50K)")
plt.show()

# %%
df["balanceDiffOrig"] = df["oldbalanceOrg"]- df["newbalanceOrig"]
df["balanceDiffdest"] = df["newbalanceDest"]- df["oldbalanceDest"]

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balanceDiffOrig', 'balanceDiffdest'],
#       dtype='str')

# %%
(df["balanceDiffOrig"] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffdest"] < 0).sum()
# Out:
# np.int64(1238864)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffdest
# 0          9839.64              0.0
# 1          1864.28              0.0

# %%
fraoud_per_step= df[df["isFraud"] == 1]["step"].value_counts().sort_index()
plt.plot(fraoud_per_step.index , fraoud_per_step.values, label = "Fraoud per Step")
plt.xlabel("Step (Time)")
plt.ylabel("Number of Fraouds")
plt.title("Fraoud over Time")
plt.grid(True)
plt.show()

# %%
df.drop(columns="step", inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffdest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
top_senders = df["nameOrig"].value_counts().head(10)
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_receivers = df["nameDest"].value_counts().head(10)
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraoud_users =  df[df["isFraud"] == 1] ["nameOrig"].value_counts().head(10)
fraoud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraoud_types = df[df["type"].isin(["TRANSFER", "CASH OUT"])]
fraoud_types["type"]. value_counts()
# Out:
# type
# TRANSFER    532909
# Name: count, dtype: int64

# %%
sns.countplot(data = fraoud_types, x = "type", hue = "isFraud")
plt.title("Fraud Distribution in Transfer & Cash_Out")
plt.show()

# %%
corr = df[["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest", "isFraud"]].corr()
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
zero_after_transfer = df[(df
                        ["oldbalanceOrg"]>0 ) & 
                        (df["newbalanceOrig"] == 0 ) &
                        (df["type"].isin(["TRANSFER", "CASHOUT"]))]

# %%
len(zero_after_transfer)
# Out:
# 228662

# %%
zero_after_transfer.head()
# Out:
#          type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2    TRANSFER     181.00  C1305486145         181.00             0.0
# 19   TRANSFER  215310.30  C1670993182         705.00             0.0
# 24   TRANSFER  311685.89  C1984094095       10835.00             0.0
# 78   TRANSFER   42712.39   C283039401       10363.39             0.0
# 123  TRANSFER  330757.04  C1494346128      103657.00             0.0
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2     C553264065            0.00            0.00        1               0
# 19   C1100439041        22425.00            0.00        0               0
# 24    C932583850         6267.00      2719172.89        0               0
# 78   C1330106945        57901.66        24044.18        0               0
# 123   C564160838        79676.00      1254956.07        0               0
#
#      balanceDiffOrig  balanceDiffdest
# 2             181.00             0.00
# ...

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,  confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffdest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
df_model = df.drop(["nameOrig", "nameDest", "isFlaggedFraud"], axis= 1)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrig  balanceDiffdest
# 0             0.0        0          9839.64              0.0
# 1             0.0        0          1864.28              0.0
# 2             0.0        1           181.00              0.0
# 3             0.0        1           181.00         -21182.0
# 4             0.0        0         11668.14              0.0

# %%
categorical = ["type"]
numeric = ["amount", "oldbalanceOrg", "oldbalanceDest", "newbalanceDest"]

# %%
y = df_model["isFraud"]
X = df_model.drop("isFraud", axis=1 )

# %%
X_train, X_test , y_train, y_test = train_test_split(X, y, test_size= 0.3, stratify=y)

# %%
Preprocessor = ColumnTransformer(
    transformers= [
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(drop="first"), categorical)
    ],
    remainder= "drop"
)

# %%
pipeline = Pipeline([
    ("prep", Preprocessor),
    ("clf", LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
# y_pred = pipeline.predict(X_test)
y_pred_proba = pipeline.predict_proba(X_test)[:,1]
y_pred = (y_pred_proba > 0.2).astype(int)  # adjust threshold
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.82   1906322
#            1       0.00      1.00      0.01      2464
#
#     accuracy                           0.69   1908786
#    macro avg       0.50      0.84      0.41   1908786
# weighted avg       1.00      0.69      0.81   1908786

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1311529,  594793],
#        [      6,    2458]])

# %%
pipeline.score(X_test , y_test) * 100
# Out:
# 93.102631725086

# %%
import joblib 

joblib.dump(pipeline , "fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']

# %%
import joblib, pandas as pd

model = joblib.load("fraud_detection_pipeline.pkl")
print(model.feature_names_in_)
# Out:
# ['type' 'amount' 'oldbalanceOrg' 'newbalanceOrig' 'oldbalanceDest'
#  'newbalanceDest' 'balanceDiffOrig' 'balanceDiffdest']
